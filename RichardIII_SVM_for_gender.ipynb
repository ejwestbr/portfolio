# %% [markdown]
# # Read in data

# %%
import pandas as p
train=p.read_csv("/Users/Elizabeth's/Documents/Folger_Digital_Texts_Complete/richardIII_gender_lite.csv", delimiter=',')

# %%
train.dropna(axis=0, inplace=True)
train
# Out:
#         speaker   sex                                              lines
# 77      RICHARD  male                Now is the winter of our discontent
# 78      RICHARD  male          Made glorious summer by this son of York,
# 79      RICHARD  male      And all the clouds that loured upon our house
# 80      RICHARD  male             In the deep bosom of the ocean buried.
# 81      RICHARD  male   Now are our brows bound with victorious wreaths,
# ...         ...   ...                                                ...
# 4485   RICHMOND  male    And make poor England weep in streams of blood.
# 4486   RICHMOND  male   Let them not live to taste this land’s increase,
# 4487   RICHMOND  male  That would with treason wound this fair land’s...
# 4488   RICHMOND  male   Now civil wounds are stopped, peace lives again.
# 4489   RICHMOND  male         That she may long live here, God say amen.
#
# [3765 rows x 3 columns]

# %%
y=train['sex'].values
X=train['lines'].values

# %% [markdown]
# ### Split train/test data for hold-out test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
print(X_train[0])
print(y_train[0])
print(X_test[0])
print(y_test[0])
# Out:
# (2635,) (2635,) (1130,) (1130,)
# That in the sty of the most deadly boar
# male
# And give him from me this most needful note.
# male

# %% [markdown]
# ### Data Checking

# %%
# Check how many training examples in each category

training_labels = set(y_train)
print(training_labels)
from scipy.stats import itemfreq
training_category_dist = itemfreq(y_train)
print(training_category_dist)
# Out:
# {'female', 'male'}
# [['female' 571]
#  ['male' 2064]]
# C:\Users\Elizabeth's\AppData\Local\Temp\ipykernel_1016\3872649012.py:6: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
#   training_category_dist = itemfreq(y_train)

# %%
testing_labels = set(y_test)
print(testing_labels)
testing_category_dist = itemfreq(y_test)
print(testing_category_dist)
# Out:
# {'female', 'male'}
# [['female' 259]
#  ['male' 871]]
# C:\Users\Elizabeth's\AppData\Local\Temp\ipykernel_1016\2160331475.py:3: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
#   testing_category_dist = itemfreq(y_test)

# %% [markdown]
# ## Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk.stem

snowball_stemmer = nltk.stem.SnowballStemmer('english')
class StemmedCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(StemmedCountVectorizer, self).build_analyzer()
        return lambda doc: ([snowball_stemmer.stem(w) for w in analyzer(doc)])

# %%
# unigram_count_vectorizer = CountVectorizer(encoding='latin-1', binary=False, min_df=5, stop_words='english')
#unigram_count_vectorizer = CountVectorizer( binary=False, min_df=3 , max_df = 0.9, stop_words= 'english')
unigram_count_vectorizer_stem = StemmedCountVectorizer(binary=False, min_df=3 ,max_df = 0.9, stop_words= 'english')

#  bigrams
#gram12_count_vectorizer = CountVectorizer(ngram_range=(1,2), min_df=3, max_df = 0.9, stop_words= 'english')
gram12_count_vectorizer_stem = StemmedCountVectorizer(ngram_range=(1,2), min_df=3, max_df = 0.9, stop_words= 'english')

# %% [markdown]
# ## Vectorize the training data

# %%
# fit vocabulary in training documents and transform the training documents into vectors
X_train_vec_stem = unigram_count_vectorizer_stem.fit_transform(X_train)

# check the content of a document vector
print(X_train_vec_stem.shape)
X_train_vec_stem[0].toarray()

# check the size of the constructed vocabulary
print(len(unigram_count_vectorizer_stem.vocabulary_))

# print out the first 10 items in the vocabulary
print(list(unigram_count_vectorizer_stem.vocabulary_.items())[:15])
# Out:
# (2635, 797)
# 797
# [('dead', 158), ('boar', 69), ('hath', 320), ('turn', 719), ('prayer', 516), ('head', 323), ('better', 56), ('came', 94), ('father', 245), ('just', 368), ('small', 628), ('power', 514), ('tut', 720), ('thou', 696), ('art', 26)]

# %%
# fit vocabulary in training documents and transform the training documents into vectors
X_train_gram_vec_stem = gram12_count_vectorizer_stem.fit_transform(X_train)

# check the content of a document vector
print(X_train_gram_vec_stem.shape)
X_train_gram_vec_stem[0].toarray()

# check the size of the constructed vocabulary
print(len(gram12_count_vectorizer_stem.vocabulary_))

# print out the first 10 items in the vocabulary
print(list(gram12_count_vectorizer_stem.vocabulary_.items())[:15])
# Out:
# (2635, 883)
# 883
# [('dead', 167), ('boar', 71), ('hath', 349), ('turn', 805), ('prayer', 566), ('head', 352), ('better', 58), ('came', 98), ('father', 262), ('just', 398), ('small', 689), ('power', 564), ('tut', 806), ('thou', 766), ('art', 26)]

# %% [markdown]
# ## Vectorize the test data

# %%
X_test_vec_stem = unigram_count_vectorizer_stem.transform(X_test)

print(X_test_vec_stem.shape)
# Out:
# (1130, 797)

# %%
X_test_gram_vec_stem = gram12_count_vectorizer_stem.transform(X_test)

print(X_test_gram_vec_stem.shape)
# Out:
# (1130, 883)

# %% [markdown]
# # Train a LinearSVC classifier

# %%
# import the LinearSVC module
from sklearn.svm import LinearSVC

# initialize the LinearSVC model
# default is 1; play with different costs
svm_clf = LinearSVC(C=1)
svm_clf_gram = LinearSVC(C=1)

# use the training data to train the model
svm_clf.fit(X_train_vec_stem,y_train)
svm_clf_gram.fit(X_train_gram_vec_stem,y_train)
# Out:
# LinearSVC(C=1)

# %% [markdown]
# ## explore and interpret trained LinearSVC model

# %%
unigram_count_vectorizer_stem.vocabulary_.get('worthless')
for i in range(0,5):
  print(svm_clf.coef_[i][unigram_count_vectorizer_stem.vocabulary_.get('worthless')])
# Out:
# [[ 5.09883643e-01  4.52189025e-01  5.54415945e-01 -3.68749837e-01
#    2.91327217e-01  5.82057462e-01 -1.03547250e-01  3.17941855e-01
#   -7.84214314e-03 -6.45474043e-01  5.14596953e-01 -6.00369188e-01
#    5.05951285e-01 -9.64536718e-01 -1.87088576e-01  8.87824359e-01
#   -1.57388957e-01  3.84743060e-01 -1.62834503e-01 -6.01817771e-02
#   -1.77056206e-01  1.36961153e-01 -7.92898248e-02  2.55916144e-01
#    4.06468094e-01  3.87013618e-01 -3.56400138e-02  6.28020532e-02
#    2.32003618e-02 -1.72245228e-01  2.55827352e-01  9.17515853e-02
#   -1.18821772e-01 -4.81257292e-01  1.50698758e-01 -1.14641087e+00
#   -6.67280944e-01  3.20859509e-01 -1.81586331e-01  3.90131221e-01
#    1.29037908e+00 -5.70059260e-03  4.45261032e-01 -7.79705981e-01
#   -4.09583531e-01 -5.65617574e-01 -3.45479006e-01 -1.19889898e-01
#    5.71661767e-01  7.98442155e-01  1.38777878e-17 -4.84311233e-01
#    5.33661006e-01 -4.34028551e-01 -2.76093519e-01 -6.02797847e-01
#    2.06433200e-01  5.03204660e-01  3.66289357e-01 -5.74612438e-02
#   -5.85971320e-01  4.72549204e-02 -1.10948043e+00  4.14635773e-01
#    1.66950350e-01  1.56140734e-01 -5.54103160e-01  2.82980777e-01
#   -5.87577021e-01  7.55948177e-01  1.72275747e-02  3.18987654e-02
#    3.31205427e-01 -5.27490996e-01  8.66252276e-02 -2.68852232e-01
#   -2.46552032e-01  5.61148795e-01  5.41429589e-01  5.41068275e-01
#   -2.01299676e-01  3.12850692e-01 -4.25748349e-01 -2.36346622e-01
#   -1.59425826e-01  2.72306206e-02  8.77284874e-02  3.17676498e-01
#   -8.69725457e-01  6.32894727e-01  2.66399391e-01 -1.08902538e+00
#   -3.68710649e-01  1.08092265e-01 -7.88363675e-02 -4.05585914e-01
#    9.07455235e-01 -2.74550508e-02  3.35147055e-01  6.79450051e-01
#   -5.40971398e-01  0.00000000e+00  9.62769334e-02  2.96427627e-01
#    6.04741627e-01 -7.93145859e-01 -4.22522730e-01  5.91221158e-01
#    7.27719661e-01 -1.53719693e-01 -2.32543455e-01  5.19312059e-01
#    3.59387626e-01  6.44696020e-01  4.97586491e-01  7.46152250e-02
#    2.44308359e-01  2.44308114e-01  7.38626660e-02  3.47335821e-01
#    6.79236138e-01 -4.10693952e-02 -6.05656161e-02  8.07067552e-01
#    7.81014412e-01  5.95968796e-01 -1.61572450e-01  2.42049591e-01
#    7.01400285e-01  2.44308516e-01  8.86841893e-02 -2.36684419e-01
#    1.06631397e+00  1.25566257e-01 -7.81105640e-01  3.82803687e-01
#    3.35535804e-01  4.35584330e-01  1.03779140e-01 -7.65554002e-01
#    2.61900784e-01  7.73650727e-01  6.78655516e-01  7.31283000e-01
#    1.74718857e-01  9.43232784e-02  1.95227417e-01 -6.63191131e-01
#   -2.16983388e-01 -1.07587125e+00 -5.40805755e-01  6.18708240e-01
#   -1.37583020e-01  1.28768418e-01 -2.16162014e-01  6.73249980e-01
#    1.17758821e-01  1.29469394e-01 -2.36713514e-01  6.40370303e-01
#   -1.65390822e-01 -2.65565161e-01 -3.62348159e-02 -5.69757288e-01
#    5.14952863e-01  6.07444163e-02  4.68832782e-02  5.61109367e-01
#    3.06330657e-01  2.08668011e-01  1.07073183e-01  3.13013515e-01
#    3.17577561e-02 -3.30041316e-02  3.43960738e-01  6.99418351e-01
#    3.11915809e-01  6.80414419e-01 -3.32741890e-01  1.21738514e-01
#   -8.47232241e-01  1.71738221e-01 -6.21040739e-01 -6.54159022e-01
#   -6.50023690e-01 -1.00425768e+00  1.19353249e-01  3.14865065e-01
#    4.21409748e-01  3.57410916e-02  5.06839246e-01 -2.32951422e-01
#    9.13813681e-01  1.94621366e-01 -5.17289067e-01 -2.52802751e-01
#    3.30228296e-02 -2.86416663e-01  1.85925159e-02  9.50141636e-02
#   -2.33819906e-01 -1.86540765e-01  1.36867496e-01  9.32804150e-02
#    3.84227518e-01  6.46760402e-01  4.53484221e-01 -4.40441444e-02
#   -1.12224901e-01 -5.14856984e-01  1.46585019e-01  6.05691738e-01
#    2.11868253e-01 -5.01610428e-01 -6.58834803e-01 -3.77943065e-02
#    3.60223004e-01  1.65802492e-01 -6.99323570e-01 -6.41037754e-02
#    3.31015054e-01  1.43968862e-01  2.00374610e-01  5.65875694e-01
#   -9.39801160e-01  2.93169979e-01  6.57589199e-01  1.98325892e-01
#    2.26769608e-01  1.78079123e-01 -2.48802748e-01  2.44308602e-01
#   -1.25280207e-01 -2.01078575e-01  4.08845554e-01 -4.09579978e-01
#    1.55220685e-01  2.78795867e-01 -1.05193606e-01  4.38216813e-01
#    5.67125970e-01  2.41513037e-01  2.44308292e-01 -3.74547916e-01
#   -4.96564719e-01  2.80626915e-01  7.41281574e-01  3.54821237e-01
#    7.44443430e-01  9.37083025e-01  8.13415199e-01 -1.91638273e-02
#    4.56619778e-01 -4.85563135e-01  3.14110905e-01  4.90254286e-01
#   -2.61344202e-03  6.26506741e-01  3.94584318e-01 -2.82608479e-02
#    4.56720986e-01  1.80272537e-01  2.90033132e-02  3.52470236e-01
#   -6.69511816e-02 -4.95810066e-01  1.29815497e-01 -4.75131289e-01
#   -2.23499586e-01  7.10263652e-01 -1.05636466e-01  2.43378266e-01
#   -5.89099667e-01  2.03360549e-01  7.23584205e-02  5.14033438e-02
#    6.64393205e-01 -4.61154084e-02 -6.52712153e-01  4.35945974e-01
#   -2.79544663e-01  4.45634174e-01 -2.94570948e-01  0.00000000e+00
#    4.10579524e-01 -1.96190848e-01  4.61147871e-01 -4.03018519e-01
#   -1.58146016e-01  1.02694088e+00 -5.49825524e-01 -2.79645804e-01
#   -1.29717771e-01  4.74627613e-01  2.64091601e-01  8.74119591e-02
#    2.46500570e-02  7.00604413e-01 -2.68429615e-01 -6.82902284e-01
#    3.61603523e-01 -3.38040315e-01  4.09178067e-01 -8.48412063e-01
#   -2.04175810e-01  2.65521785e-01 -9.67459899e-01 -7.11213853e-02
#    7.84194240e-01  1.44639452e+00  5.60005161e-01  9.12660147e-01
#   -3.07321203e-01  3.30071667e-01 -1.95773262e-01  2.44886149e-01
#    4.96224981e-02 -1.92109389e-01  9.33815785e-03 -2.38814680e-02
#   -1.01019306e-01 -9.01850838e-01 -8.93277025e-01  2.00002657e-02
#    9.05636321e-01 -3.25979835e-01  2.69145386e-01 -1.90813262e-01
#    1.84468257e-01  6.68580054e-01 -4.80478855e-01  8.40724222e-01
#   -1.22231728e+00  2.07544253e-01  6.23835028e-02 -2.96612344e-01
#   -2.93329785e-01  2.65891527e-01  1.25036269e+00  5.38133531e-01
#    7.40607877e-02  7.33932502e-01 -3.68598859e-01 -4.49412327e-01
#    1.14898960e+00 -5.54314076e-02 -3.90947760e-01 -2.54183893e-02
#   -3.77856601e-02 -1.09413259e-01 -4.77331184e-01  7.89405316e-01
#   -1.01329188e+00 -9.42560988e-02  6.04956056e-01 -1.13238256e+00
#    4.77758503e-01 -8.73005739e-01  5.48100496e-01  2.13053071e-01
#    2.89723512e-01  5.88235067e-01  3.10432069e-01  4.31859887e-01
#    1.56368796e-01  3.63317880e-01 -5.28699445e-01 -6.65975424e-01
#   -8.53750817e-02 -6.71990674e-01  5.60933108e-01 -1.85775187e-01
#   -7.52124301e-02 -3.98363477e-01  5.24944102e-01 -8.11219131e-02
#   -7.96734959e-01 -1.19307010e-01  1.16794766e-01  3.47886695e-01
#    1.36441388e+00  3.94115119e-01 -1.18885835e+00 -1.69981279e-01
#    6.61444124e-01  1.36060710e+00 -3.69621651e-01  3.15159147e-01
#    8.96317239e-01  1.85460856e-01  2.44308915e-01 -6.18621695e-02
#   -4.98603057e-01  7.56352551e-01  9.80566091e-01  1.07468037e-01
#    6.97456712e-02  4.37238117e-01  5.18444826e-01  8.22561435e-02
#    5.48106878e-01 -1.63673718e-01  1.15613718e+00  1.33478380e-01
#   -2.00100895e-01 -1.12422768e-01 -1.84496744e-02 -5.04929014e-01
#   -3.83577756e-01 -2.18734200e-01  3.46659046e-02  1.27040528e-01
#    2.48476346e-01  3.37686786e-01  3.51716121e-01 -1.29192100e+00
#   -8.10214755e-01 -9.80956406e-01  2.86622871e-01  3.72467018e-01
#   -3.50288732e-01  2.66167764e-01  7.94858828e-01 -1.70448525e-03
#    2.66712603e-01  4.39673036e-01 -5.38028020e-01  2.89357200e-01
#    2.74079620e-01  7.13979348e-01  2.30316706e-01 -1.24733810e-01
#    3.55885654e-01  1.46726411e-01  2.07205641e-01  1.71775858e-01
#    9.81246586e-01  2.00116400e-01  5.04748766e-01 -1.06134894e-01
#    6.38442028e-01  3.76634406e-01  1.63398795e-01  1.34837905e-01
#   -4.89321759e-01 -5.72615655e-01 -1.14119361e+00  8.06116286e-01
#   -5.30558119e-01  9.33601767e-02  3.48973718e-01 -8.77838590e-02
#    5.31197055e-01 -4.10910164e-01 -1.45116664e-01 -3.95694910e-01
#   -8.74837756e-02  1.23339837e-02  1.52138690e-01  2.44308286e-01
#   -3.67767817e-01  4.35252730e-01  1.52810068e-01  2.07292845e-01
#    4.80111988e-01  5.17290213e-01 -4.26864623e-01  3.35939012e-01
#   -1.47707990e-01  2.53927125e-01  7.43426601e-01  7.57381788e-01
#   -6.84443944e-01 -1.17871670e+00  2.56485619e-01 -2.44741410e-01
#    9.31344816e-02  3.02570742e-01 -4.90449081e-02  5.76035919e-01
#    4.90041230e-01 -5.06829486e-01  6.47764840e-02  6.25402248e-01
#    1.07082178e+00  3.08758729e-01 -7.41395055e-01  7.74303343e-01
#    4.20388202e-01 -7.68066106e-01  3.24486164e-01  1.17740882e-01
#    8.87600854e-01 -5.11082395e-01  5.01035899e-01  5.53527031e-01
#   -6.22779731e-01 -1.16328667e-02  1.49126214e-01  4.49933914e-01
#   -4.67321013e-01 -4.75260548e-01 -2.96545631e-02 -5.65285437e-03
#   -5.04347615e-02  6.49347155e-01  2.82949821e-01  3.40192016e-01
#    5.81614218e-01 -1.84108323e-01 -3.78175220e-01  9.64083897e-01
#   -1.10144903e-01  2.05520776e-01  6.03757533e-01 -4.57133326e-01
#    8.24086798e-02  3.54645442e-01  6.15689265e-01  3.38733108e-03
#   -1.76495311e-01  7.28834570e-01  2.93170042e-01 -1.94393366e-01
#    0.00000000e+00  6.23596881e-02 -3.36158752e-02  1.80662917e-01
#    3.20964219e-02  3.70470849e-01 -1.25529574e-01  6.76534255e-01
#   -8.02918826e-01  6.48965782e-02 -4.28582726e-01  1.63874745e-01
#   -3.97903971e-01  5.76710305e-01  5.89921915e-01  6.18260976e-01
#   -2.73245800e-01 -4.82501522e-01  1.32750692e-01  3.09245241e-01
#   -2.35625604e-01  3.56782861e-01  3.72467018e-01  1.13608024e-01
#   -3.10233448e-01  7.60284637e-01  2.65012701e-01  7.25115809e-02
#    1.46585019e-01  3.23535154e-01  8.07929701e-01 -4.97989684e-01
#    2.10819217e-01  9.45025336e-01 -3.42084007e-02  6.52239134e-01
#    3.35151911e-01  1.88947896e-01  4.53991411e-01 -5.13123372e-01
#    8.99410137e-01 -1.84782635e-02  8.27490931e-03  3.55200791e-01
#   -2.52745827e-01  1.67539352e-01 -3.64897155e-01 -8.32604768e-02
#   -3.93344589e-01  5.96162009e-01  2.61412839e-01 -1.05514736e-01
#    1.81973791e-01  1.29709876e-01 -2.49959644e-01  3.63124522e-01
#   -4.62125538e-01  3.58548272e-01 -1.14636350e-01 -5.74692955e-01
#   -9.18520674e-02 -1.01138177e-01 -2.83383039e-01  1.91088273e-01
#   -1.31876990e+00 -2.20753233e-01  8.33989813e-02  4.76632154e-01
#    5.42916527e-01 -2.65413529e-02  2.13052882e-01 -2.08166817e-17
#    1.28457364e-01 -1.67929420e-01 -7.54788865e-01 -7.21756595e-02
#    2.44308447e-01  2.56368987e-01  7.16234108e-01 -2.61407535e-01
#   -4.82510060e-01 -8.99956690e-02 -2.51256366e-01 -3.00933359e-01
#   -4.68531478e-01  9.24543627e-01 -4.62840642e-01  7.58987737e-01
#   -1.84179670e-01  4.86993579e-01  1.65017865e-01 -1.81283194e-01
#    3.32998469e-01  5.74732150e-01 -9.66840972e-02  5.43961245e-01
#   -2.04155334e-01  4.26650351e-01  3.64711004e-01 -1.85074857e-01
#   -6.90943913e-01 -8.03280576e-01 -1.96908679e-01 -9.85640913e-01
#   -7.00992946e-01 -9.32036455e-02  4.82563544e-01  4.37556527e-01
#    7.97732592e-01 -1.99399764e-01 -1.30978730e-01 -7.40509010e-01
#   -5.42381369e-02 -3.70818246e-01  5.37523433e-02  2.10590563e-01
#    5.44338348e-01  2.18208252e-01  2.80298624e-01  2.81262898e-01
#   -8.17118623e-02  1.95967389e-01  1.57051543e-01 -1.78794764e-01
#    2.13943581e-01  7.00386653e-01  9.02015898e-01  1.03569583e+00
#    1.17060615e-01 -1.83911472e-01  2.62519706e-01  5.32261183e-02
#    1.76408210e-01 -6.31249992e-02  4.54167187e-01  3.36558141e-01
#   -4.27857964e-01  3.47904406e-01  3.32645907e-01  6.84230830e-01
#   -1.31897071e+00 -1.02554880e-01 -1.33507799e-01 -1.22870141e-01
#    2.44308280e-01  9.75201204e-01 -4.63773634e-01 -2.27148112e-01
#   -1.77369798e-01  5.76455504e-01  2.36902700e-01  4.56945219e-01
#    9.60358622e-01  7.69161660e-01 -1.33528228e+00  1.52133399e-02
#   -5.82537748e-01  2.16299987e-01  4.52148834e-01 -5.84338816e-01
#    3.71989414e-01 -1.39673327e-01 -5.42074603e-01 -1.23890873e-02
#   -3.89554596e-01  1.11267546e-01 -4.73545108e-01 -5.18420300e-01
#   -2.50163290e-01  7.84231482e-02  5.91004513e-03  3.44655474e-02
#   -5.10757634e-01  4.06388407e-01  1.00088504e-01 -3.04405896e-04
#   -3.75926815e-01 -4.43951600e-01 -1.17747248e-01  1.51906716e-01
#    1.17028656e-02 -8.34512988e-01  6.98184183e-01  7.83930788e-01
#   -2.81944536e-03  1.27863267e-01  7.65291337e-01  5.37908885e-02
#    9.54679304e-02  1.39767850e-01 -1.18708131e+00 -5.29491428e-02
#   -7.30693414e-02  1.67763021e-01  4.61321531e-01 -4.02643768e-02
#    7.93230570e-01  1.08911459e+00  3.77397947e-01  6.77126683e-01
#   -2.86543060e-02  3.59114564e-01 -1.38521391e-01  2.57699962e-01
#    1.40783651e-02  4.87484048e-01  1.04273881e-02 -6.23841575e-01
#    3.14764171e-01 -2.33340838e-01  2.22409186e-01 -1.71916568e-01
#   -2.73513317e-01 -8.85596039e-01 -1.66290117e-01 -1.85465973e-01
#   -4.79751701e-01  2.44308264e-01 -5.36016771e-02  7.69215955e-01
#   -5.20498430e-01  2.64160919e-01  8.17226153e-01 -1.00252784e+00
#    2.78537283e-01 -8.90775693e-03 -5.27658065e-01  7.17938972e-02
#   -6.92163584e-01  2.99980934e-01 -2.08947809e-01  0.00000000e+00
#    4.26808355e-01 -7.95440722e-01 -1.08671812e+00  2.37616132e-01
#    7.79412286e-01  2.44308428e-01 -8.23774102e-02 -2.81327244e-01
#   -4.91729736e-01  0.00000000e+00 -5.72357212e-01  1.22150433e-02
#    3.73488648e-01  8.31024713e-01 -7.75076000e-01 -2.96909828e-01
#    3.18877561e-01  1.22439454e-01 -6.74855628e-01  4.34195879e-01
#    1.21025837e+00 -7.00636860e-01  2.92840661e-01  4.02466709e-01
#   -2.04882300e-01 -4.99443283e-01  6.89651001e-01  9.33561560e-02
#    8.73583245e-01 -2.91654150e-01  1.41220317e-01 -3.38153587e-01
#    9.21334559e-03 -2.74919162e-01 -4.22106238e-01  4.56198527e-01
#    1.10708001e-01 -1.97912281e-01 -7.59045092e-01 -2.47570123e-01
#    2.88488977e-01]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 unigram_count_vectorizer_stem.vocabulary_.get('worthless')
#       2 for i in range(0,5):
# ----> 3   print(svm_clf.coef_[i][unigram_count_vectorizer_stem.vocabulary_.get('worthless')])
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
gram12_count_vectorizer_stem.vocabulary_.get('worthless')
for i in range(0,5):
  print(svm_clf_gram.coef_[i][gram12_count_vectorizer_stem.vocabulary_.get('worthless')])
# Out:
# [[ 4.00148139e-01  6.04622754e-01  5.61857062e-01 -1.93284402e-01
#    2.80892667e-01  5.85469252e-01 -2.06325459e-02  2.35263563e-01
#   -5.10047499e-02 -8.70847064e-01  5.08621951e-01 -5.87477900e-01
#    4.93790169e-01 -9.50574600e-01 -2.96128613e-01  9.16431432e-01
#    2.41976775e-01  4.26381679e-01 -2.72313299e-01  1.64493657e-02
#   -1.52376408e-01  2.64149788e-01 -5.88630538e-02  2.70596389e-01
#    4.21301046e-01  4.08956108e-01 -1.07126032e-01  8.24893657e-02
#    5.84624528e-02  1.49732506e-02 -8.25662736e-02  2.61403080e-01
#    8.14675100e-02 -5.30383520e-02 -5.43345026e-01  1.26740418e-01
#   -1.14865506e+00 -6.79967667e-01  9.63156316e-02 -1.78256204e-01
#    4.40562250e-01  1.20158200e+00  1.22089068e-01 -6.70849335e-01
#    4.70342295e-01 -7.66034014e-01 -4.25685962e-01 -5.76499777e-01
#   -3.70986076e-01 -1.37225737e-01  5.54657120e-01  9.61814358e-01
#    0.00000000e+00 -4.63280741e-01  5.16811237e-01 -4.03708980e-01
#   -2.75054918e-01 -6.75557212e-01  2.17596947e-01  3.90555158e-01
#    3.94280835e-01 -1.46608464e-01 -3.86682832e-01  6.96956383e-02
#   -1.15126402e+00  2.96909031e-01  1.80158536e-01  2.27187937e-01
#   -5.25729120e-01  2.79700922e-01 -7.93337184e-01  6.61846339e-01
#   -1.75236707e-01 -2.21068777e-02  3.33550432e-01 -4.01384613e-01
#    9.86175530e-02 -2.68165904e-01 -2.51061344e-01  5.75495986e-01
#    5.53832997e-01  5.35486036e-01 -2.08175177e-01  1.84750286e-01
#   -3.84166785e-01 -2.89621474e-01 -1.64265697e-01 -5.05619720e-03
#    6.92214415e-01  4.83988359e-01  1.02622694e-01  4.77596269e-01
#   -9.07828872e-01  6.94244629e-01  2.47671834e-01 -1.08566138e+00
#   -3.08536561e-01  7.66658426e-02 -9.27539346e-02 -3.10725429e-01
#   -3.10725429e-01  6.92822822e-01 -1.51541970e-02  3.84217575e-01
#    6.85480024e-01 -4.85197382e-01  1.38777878e-17  0.00000000e+00
#    2.84682655e-01  5.60304911e-01 -7.46268875e-01 -4.22693491e-01
#    6.09917467e-01  7.69491249e-01 -1.79421306e-01 -1.37348134e-01
#    5.29720905e-01  3.69273696e-01  8.17860560e-01  4.43127151e-01
#   -6.76378333e-02  2.47671799e-01  2.47671676e-01  3.16365062e-02
#    3.07968711e-01  6.68461684e-01  1.73601908e-01 -9.30766458e-01
#    3.86091792e-02 -3.25950643e-01 -2.09841889e-02  7.23272737e-01
#    7.89241951e-01  5.15261457e-01 -2.61307077e-01  2.33791686e-01
#    7.06277237e-01  2.47671633e-01  4.66539714e-02 -3.52539824e-01
#    1.06739631e+00  8.59062705e-02 -7.90169365e-01  2.97730814e-01
#    2.58530489e-01  3.71574548e-01  1.85486837e-01 -7.36043991e-01
#    2.84669830e-01  7.15558495e-01  6.93889390e-18  6.85254322e-01
#    9.93852499e-01  1.59759676e-01  1.12636887e-01  1.61260035e-01
#   -6.83216511e-01 -2.68432690e-01 -1.15532081e+00 -4.96946054e-01
#    7.09153889e-01 -2.05302665e-01  4.74880599e-02 -1.51812984e-01
#    7.91740259e-01  2.06061404e-02  7.27813163e-02 -2.40330990e-01
#    6.32988190e-01 -4.98158894e-02 -2.77601192e-01 -8.95594061e-03
#   -5.97852634e-01  3.85216556e-01  5.29793055e-02  5.59178618e-02
#    6.04273885e-01  3.19880298e-01  2.20254681e-01  6.40392367e-02
#    3.13701428e-01  3.01627863e-02 -2.30539336e-02  2.66646617e-01
#    7.13115766e-01 -4.05719300e-01  1.33853854e+00  8.06812528e-01
#   -3.01077996e-01  2.25976171e-01 -7.80865219e-01  1.18445396e-01
#   -8.22305283e-01 -8.38710900e-01 -6.22335978e-01 -9.63153241e-01
#    1.65121832e-01  3.26084055e-01  6.36616188e-01  1.24504837e-01
#    4.08022015e-01 -2.66513712e-01  8.89774625e-01  2.64142231e-01
#   -5.43711158e-01 -2.18471494e-01 -4.68040119e-01  1.32123189e-01
#   -3.25422361e-01  3.46772812e-02  1.06811586e-01 -1.87293634e-01
#   -1.42342159e-01  2.22650015e-01  7.61836854e-02  3.62687038e-01
#    6.54562438e-01  2.92433820e-01  6.84413118e-01  5.13294296e-01
#    6.18941354e-02 -1.45057253e-01 -5.31990859e-01  1.51456790e-01
#    6.31631734e-01  7.96853567e-02 -5.19463414e-01 -6.05147138e-01
#   -3.86575533e-02 -2.43828756e-01 -7.07344138e-01  6.84724528e-01
#    3.98014911e-01  2.50055479e-01 -6.98895753e-01 -1.23372848e-01
#    3.68293222e-01  3.86528721e-01  1.38296580e-01  1.98102702e-01
#    5.66328003e-01 -9.41855307e-01  2.97205987e-01  6.74661989e-01
#    2.28595610e-01  2.95406303e-01  2.17097664e-01 -2.81250773e-01
#    2.68093459e-01 -1.22738132e-01 -2.71342821e-01  3.95753781e-01
#   -3.30293426e-01  1.60413971e-01  1.59237909e-01 -1.00919610e-01
#    4.34936998e-01  5.40311643e-01  4.00871874e-02  2.47671609e-01
#   -3.35858268e-01 -4.90982965e-01  2.24527588e-01  2.65892129e-01
#    4.83988359e-01  3.64714037e-01  7.62908267e-01  9.86996925e-01
#    1.10485027e+00 -1.11686456e-01  5.30055276e-01 -6.17445237e-01
#    3.18434730e-01  4.41510293e-01 -5.77980782e-02  5.35979130e-01
#    3.81070338e-01 -3.23449741e-02  5.10968029e-01  1.63172330e-01
#    1.37662984e-01  3.55662153e-01  7.68636279e-02 -5.33172498e-01
#    1.81461578e-01 -4.23278317e-01 -1.39787271e-01  7.23461587e-01
#   -1.76632239e-01  2.29360290e-01 -7.14481956e-01  1.56001105e-01
#    8.34957701e-02  7.20863396e-02  6.57038271e-01 -1.86427551e-02
#   -6.56711692e-01  4.27238827e-01 -4.09278705e-01  4.29484274e-01
#   -2.08373182e-01  0.00000000e+00  3.74035351e-01 -2.35860940e-01
#    3.59988159e-01 -7.47003576e-01 -1.55169113e-01  1.65376702e-01
#    2.91232139e-01 -6.33983274e-01  9.61858532e-01 -6.88788552e-01
#   -3.06693189e-01 -9.07013547e-02 -3.21840934e-01  9.50041774e-01
#    5.59325596e-01  1.38777878e-17  1.49497331e-01  3.31092731e-01
#   -6.18351458e-01  4.94995852e-01  2.24667882e-01  4.20855833e-02
#    4.81437772e-02  1.20061605e-01  7.07755660e-01 -1.25314947e-01
#   -6.30958444e-01  5.11325553e-01 -1.66053730e-01  3.62983087e-01
#   -8.06835218e-01 -2.01386099e-01  2.79116341e-01 -9.50961552e-01
#   -6.20576724e-02  8.40710453e-01  1.52928139e+00  5.56895265e-01
#    9.51603702e-01 -6.13426141e-02  3.16122494e-01 -1.82359655e-01
#    2.12326425e-01  1.60278000e-02 -1.89044183e-01  3.29848163e-01
#    3.28502480e-03 -7.45104428e-02 -9.34011842e-01 -8.96160960e-01
#   -8.80074660e-03  8.91491158e-01 -3.11929583e-01  2.87442147e-01
#   -9.31619300e-02 -5.59726413e-01  1.61306831e-01  6.32894661e-01
#   -5.66849389e-01  8.87125262e-01 -1.26363749e+00  1.43132606e-01
#    1.90060161e-01 -3.46916667e-01 -3.06548889e-01  1.88679580e-01
#    1.20219400e+00  5.22697056e-01  1.66707452e-02  7.50674631e-01
#   -4.09118994e-01 -4.34151525e-01  1.12238837e+00 -8.96605588e-02
#   -4.09631408e-01 -3.61423231e-02 -6.06318894e-03 -8.63326039e-02
#   -4.28879570e-01  8.42890237e-01 -9.75659253e-01 -7.59642406e-02
#    5.71136949e-01 -1.21377848e+00  8.09872069e-01 -8.69525572e-01
#    6.27880544e-01  2.10393477e-01  2.34228546e-01  5.84421242e-01
#    3.78718988e-01  4.86220436e-01  1.97125338e-01  6.49688556e-01
#   -3.38338234e-01 -6.01150429e-01 -3.26705467e-01 -6.91124053e-01
#    6.42423466e-01 -1.52414355e-01  6.12198654e-02 -5.49146244e-02
#   -2.28714059e-01  5.92906848e-01 -1.25373903e-01  3.17923508e-01
#    1.02057853e+00  1.56348121e-01 -2.20584049e-01 -8.48640491e-01
#   -2.01507040e-01  1.70355787e-01  3.67430070e-01  7.67056618e-01
#    1.33913388e+00  3.80880081e-01 -1.16630920e+00 -1.68547238e-01
#    7.24789924e-01  1.44818453e+00 -3.67016037e-01  3.94631629e-01
#    7.15952782e-01  6.11590285e-02  2.53513360e-01 -1.66789362e-02
#   -5.20134396e-01  7.80324332e-01  1.03105259e+00  2.32981949e-01
#    5.28554994e-03  3.45812516e-01  5.78023317e-01  5.85515038e-02
#    5.16092757e-01 -1.61524477e-01  1.25073318e+00  1.35256803e-01
#   -1.23643170e-01 -8.47114563e-01 -1.19372892e-01  4.03532134e-02
#   -7.59405928e-01 -5.16764213e-01 -3.87504190e-01 -2.89334621e-01
#    0.00000000e+00  1.37194318e-01  2.41568804e-01  3.34517472e-01
#    0.00000000e+00  0.00000000e+00  4.13779082e-01  0.00000000e+00
#    2.91999662e-01  3.71380952e-01 -1.31421952e+00 -7.84262747e-01
#   -9.76361090e-01  3.19899661e-01  4.05794173e-01  0.00000000e+00
#   -3.15367207e-01  2.81603949e-01  7.56343533e-01 -6.68781897e-03
#    2.72483574e-01  4.50539991e-01 -6.92372199e-01  5.43835283e-01
#    2.63378409e-01  2.94975353e-01  6.34225458e-01  1.78748098e-01
#   -2.10674161e-01  3.25923512e-01  2.09853445e-01  1.92735409e-01
#    1.57834293e-01  9.84439273e-01  2.61250173e-01  5.06149954e-01
#   -4.75162940e-02  8.49943280e-01  3.45170915e-01  1.38777878e-17
#    1.15465829e-01  1.62852775e-01 -4.87521628e-01 -5.70283425e-01
#   -1.07001200e+00  7.70313801e-01 -4.88889703e-01  1.17649550e-01
#    3.21188873e-01 -7.24316776e-02  3.31092731e-01 -4.01619886e-01
#   -1.90364000e-01 -3.52187939e-01 -8.51433609e-02  2.88390714e-02
#    8.46242675e-02  2.48243978e-01 -3.20891461e-01  4.64621484e-01
#    1.23537438e-01  1.09231617e-01  2.82076053e-01  5.68173372e-01
#   -3.99176714e-01  2.49222121e-01 -1.85563884e-01  1.98993576e-01
#    8.67178791e-02  2.15056651e-01  0.00000000e+00  7.27194880e-01
#    6.39088581e-01 -6.90125633e-01 -1.23971270e+00  2.92925751e-01
#   -1.86050097e-01  6.65239534e-02  3.17222351e-01 -1.34597406e-02
#    8.44824507e-01  5.20418069e-01 -5.02793726e-01  1.17225617e-01
#    6.39721410e-01  1.12279039e+00  3.23113075e-01 -6.97573218e-01
#    7.72250154e-01  3.56848633e-01 -7.98979112e-01  3.23969677e-01
#    1.07957146e-01  7.83541979e-01 -5.39787126e-01  5.07695292e-01
#    4.85312887e-01 -6.09153759e-01 -4.07517777e-03  1.71052019e-01
#    3.99945533e-01 -4.70457928e-01 -4.91736036e-01 -2.51943916e-02
#    4.64705804e-03  8.40358464e-02  6.40552069e-01  2.99152947e-01
#    3.03966527e-01  6.63432396e-01 -1.21657883e-01 -3.04910096e-01
#    8.24004960e-01 -3.29501749e-01  1.25983145e+00  2.34755278e-01
#    6.29746429e-01 -4.00022477e-01  8.74484210e-02  3.06666149e-01
#    6.66158343e-01  2.08206996e-02 -1.20936655e-01  6.62658747e-01
#    3.15547440e-01 -2.34286707e-01  0.00000000e+00  8.07692171e-03
#    4.63188309e-03 -5.40863395e-01  1.79497759e-01  5.17799710e-02
#    5.81009647e-01 -1.19304593e-01  6.43249319e-01 -7.86345272e-01
#   -1.00558894e-01 -4.21057007e-01  1.75679825e-01 -4.24583772e-01
#    5.99078855e-01  6.44550327e-01  6.33124157e-01 -2.69490594e-01
#   -4.62714870e-01  1.42030366e-01  1.70913441e-01 -3.00975556e-01
#    3.30437184e-01  4.05794173e-01  1.36118411e-02 -3.49164918e-01
#    7.52065651e-01  2.42754923e-01  7.62441044e-02  1.46700910e-01
#    1.97631006e-01  6.07710745e-01 -6.22411321e-01  2.00047464e-01
#    8.37955925e-01  1.44367896e-02  5.06796418e-01  3.66529700e-01
#    1.85598706e-01  3.45580194e-01 -5.25001672e-01  8.36440438e-01
#   -3.93552067e-02  6.18270844e-02  4.08133970e-01 -1.58480636e-01
#   -7.86433209e-01  3.76681893e-01 -8.35204794e-01 -3.79918391e-01
#   -5.70990048e-02 -2.04831431e-01 -3.83776947e-01  5.45267131e-01
#    2.53164295e-01 -1.06176484e-01  1.43366643e-01  1.95176049e-01
#   -3.39786878e-01  2.96404483e-01  2.49144355e-02 -4.47642569e-01
#    3.41058072e-01 -2.00699024e-01 -1.58658671e-01 -1.03035488e-01
#   -6.23526721e-04 -8.03397316e-01  2.10143565e-01  1.10803021e-01
#   -2.40957482e-01  1.97673612e-01 -1.35779008e+00 -1.72866713e-01
#    7.49971852e-02  6.72239605e-01  5.51899781e-01 -4.14491347e-02
#    2.10392969e-01  1.38777878e-17  1.47313443e-01 -1.48016791e-01
#   -6.79582845e-01 -1.48712204e-01  2.47672058e-01  2.21811135e-01
#    7.36892995e-01 -2.38908916e-01 -4.31763233e-01 -3.51684295e-02
#   -8.07508295e-01 -6.84946546e-01 -2.70723569e-01  1.72139557e-01
#   -4.58460079e-01 -4.86550630e-01  8.11626839e-01 -4.76415911e-01
#    8.19817581e-01 -1.86858475e-01  4.44560518e-01  6.27708885e-02
#   -1.78665352e-01  3.31214368e-01  6.44029201e-01 -6.89995078e-02
#    6.49688556e-01 -4.93396143e-01  4.25229724e-01  4.30257746e-01
#   -2.61902279e-01 -6.34382994e-01 -9.27760568e-01 -2.23026139e-01
#   -9.77045459e-01 -6.64379040e-01 -1.12356774e-01  5.20715604e-01
#    3.19437776e-01  8.11867044e-01 -1.12043935e-01  6.93889390e-18
#   -9.48151709e-03 -7.15276096e-01 -7.21943622e-02  4.11505177e-01
#   -5.65548926e-01  2.93412368e-02  3.08279573e-01  5.99158219e-01
#    2.05232144e-01  1.98185264e-01  3.07445904e-01 -5.97200168e-02
#    1.96842291e-01 -1.26989240e-01  4.63444948e-01 -1.81229856e-01
#    3.08135174e-01  6.11076296e-01  8.96005540e-01  1.02826840e+00
#   -3.39523801e-02 -1.56979103e-01  3.07445601e-01  3.44040043e-02
#    1.82856875e-01 -4.34227204e-02  4.52651937e-01  2.69167011e-01
#   -4.30522798e-01  3.47409995e-01  3.28590369e-01  6.55700768e-01
#   -1.32974258e+00 -6.73546117e-02 -1.29379420e-01 -1.14234003e-01
#    2.47671933e-01  9.91195700e-01 -1.20647020e-02 -2.54614135e-01
#    4.77962545e-02  5.08157408e-01  4.84409431e-01  1.57604937e-01
#    4.65576208e-01  9.34717036e-01  7.68220934e-01 -1.28144045e+00
#    2.45083221e-02 -6.03494969e-01  2.37783080e-01  7.14570390e-01
#    4.24364552e-01 -5.59749247e-01  3.45399482e-01 -2.42345151e-01
#   -5.75938955e-01  2.30401768e-01 -9.22909237e-01 -3.76343245e-01
#    1.54779144e-01  1.04687140e-01 -4.63836055e-01 -5.95318259e-01
#    2.09399586e-01 -2.03097943e-01  1.11881645e-01  2.59337573e-01
#   -1.67547542e-03  6.93289160e-02 -3.88063985e-01 -1.89615398e-01
#    2.24355898e-01  9.09140169e-01 -6.13426141e-02 -1.52424935e+00
#   -6.25339613e-01 -5.14351517e-01 -4.58165214e-01  3.65234613e-01
#    8.48028383e-02  7.28483769e-03 -8.05794931e-02  7.30964618e-01
#   -6.75637543e-01 -9.25859183e-01  5.55404279e-01 -5.61787478e-01
#   -4.12316921e-01 -3.99206611e-02 -1.02332356e-01  3.14292014e-01
#    1.07288647e-02  1.20061605e-01  2.61683837e-02 -8.09642696e-01
#    7.07695262e-01  7.91619473e-01  1.41494057e-01  1.38680600e-01
#    7.36871456e-01  5.60439301e-02  1.02261155e-01  4.89280153e-02
#   -1.17089498e+00 -6.01554597e-02 -1.33216445e-01  1.94597922e-01
#    8.10287839e-01 -5.74316534e-02  1.07755445e+00  1.11075351e+00
#    3.69894330e-01  6.53659747e-01 -1.66783693e-02  3.73067553e-01
#   -1.50383867e-01  2.67961082e-01  1.06720877e-02  5.21095668e-01
#   -3.35061039e-02 -6.15728502e-01  2.67514180e-01 -3.54470753e-01
#    2.41825857e-01 -1.51221332e-01 -2.66336721e-01 -8.81408010e-01
#   -1.86290984e-01 -2.58344474e-01 -4.62830697e-01  2.47671845e-01
#   -3.08181126e-02  8.53296853e-01 -4.96085141e-01  2.94386870e-01
#    7.85264527e-01 -1.05589803e+00  3.45065670e-01  2.15798164e-02
#   -7.41453222e-01 -2.10134330e-03 -4.58165214e-01  3.16670182e-01
#   -2.61376920e-01  0.00000000e+00  4.96601444e-01 -7.69263088e-01
#   -1.07527248e+00  1.72676986e-01  7.41401940e-01  2.47671853e-01
#   -1.42333417e-01 -3.57822607e-01 -5.39303765e-01  0.00000000e+00
#   -6.69854051e-01  1.99909372e-01  5.63326195e-01  8.29523343e-01
#   -6.84908408e-01 -3.46415123e-01  3.65162914e-01  1.63979966e-01
#   -6.78933033e-01  4.76426416e-01  1.11617261e+00 -6.90465586e-01
#    2.64462412e-01  3.38290300e-01 -2.03064379e-01 -5.15192479e-01
#    6.91664699e-01  8.95079052e-02  6.04438985e-01 -2.91947625e-01
#    1.43120906e-01 -2.57444180e-01 -1.82102223e-02  3.61596587e-02
#   -5.54529907e-01  3.04783072e-01  6.08597853e-02 -2.48228561e-01
#   -8.14662473e-01 -2.16820387e-01  2.86738836e-01]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 gram12_count_vectorizer_stem.vocabulary_.get('worthless')
#       2 for i in range(0,5):
# ----> 3   print(svm_clf_gram.coef_[i][gram12_count_vectorizer_stem.vocabulary_.get('worthless')])
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
def show_most_and_least_informative_features(vectorizer, clf, class_idx=0, n=10):
    feature_names = vectorizer.get_feature_names_out()
    coefs_with_fns = sorted(zip(clf.coef_[class_idx], feature_names)) 
    top = zip(coefs_with_fns[:n], coefs_with_fns[-n:])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print('\t%.4f\t%-15s\t\t%.4f\t%-15s' % (coef_1, fn_1, coef_2, fn_2))

# %%
show_most_and_least_informative_features(unigram_count_vectorizer_stem, svm_clf, class_idx=0,  n=10)
# Out:
# 	-1.3353	teach          		1.0708	pardon
# 	-1.3190	subject        		1.0891	twas
# 	-1.3188	scene          		1.1490	hors
# 	-1.2919	lose           		1.1561	light
# 	-1.2223	hell           		1.2103	woman
# 	-1.1889	lament         		1.2504	hither
# 	-1.1871	trembl         		1.2904	bastard
# 	-1.1787	oath           		1.3606	late
# 	-1.1464	babe           		1.3644	ladi
# 	-1.1412	miseri         		1.4464	guess

# %%
show_most_and_least_informative_features(gram12_count_vectorizer_stem, svm_clf_gram, class_idx=0, n=10)
# Out:
# 	-1.5242	thou hast      		1.1224	hors
# 	-1.3578	scene          		1.1228	pardon
# 	-1.3297	subject        		1.2016	bastard
# 	-1.3142	lose           		1.2022	hither
# 	-1.2814	teach          		1.2507	light
# 	-1.2636	hell           		1.2598	poor clar
# 	-1.2397	oath           		1.3385	despair di
# 	-1.2138	infect         		1.3391	ladi
# 	-1.1709	trembl         		1.4482	late
# 	-1.1663	lament         		1.5293	guess

# %% [markdown]
# ## Test the LinearSVC classifier

# %%
# test the classifier on the test data set, print accuracy score

svm_clf.score(X_test_vec_stem,y_test)
# Out:
# 0.7707964601769911

# %%
svm_clf_gram.score(X_test_gram_vec_stem,y_test)
# Out:
# 0.7707964601769911

# %%
from sklearn.metrics import confusion_matrix
y_pred = svm_clf.predict(X_test_vec_stem)
cm = confusion_matrix(y_test, y_pred, labels=['male','female'])
print(cm)
print()

from sklearn.metrics import classification_report
target_names = ['male','female']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# [[784  87]
#  [172  87]]
#
#               precision    recall  f1-score   support
#
#         male       0.50      0.34      0.40       259
#       female       0.82      0.90      0.86       871
#
#     accuracy                           0.77      1130
#    macro avg       0.66      0.62      0.63      1130
# weighted avg       0.75      0.77      0.75      1130

# %%
y_pred2 = svm_clf_gram.predict(X_test_gram_vec_stem)
cm2 = confusion_matrix(y_test, y_pred2, labels=['male','female'])
print(cm2)
print()

target_names = ['male','female']
print(classification_report(y_test, y_pred2, target_names=target_names))
# Out:
# [[782  89]
#  [170  89]]
#
#               precision    recall  f1-score   support
#
#         male       0.50      0.34      0.41       259
#       female       0.82      0.90      0.86       871
#
#     accuracy                           0.77      1130
#    macro avg       0.66      0.62      0.63      1130
# weighted avg       0.75      0.77      0.75      1130

# %% [markdown]
# ## Interpret the prediction result

# %%
## get the confidence scores 
svm_confidence_scores = svm_clf.decision_function(X_test_vec_stem)
## get the confidence score for the first test example
print(svm_confidence_scores[0])

## Confirm by printing out the actual prediction
print(y_test[0])
# Out:
# 1.11364943778176
# male

# %% [markdown]
# ## Error Analysis

# %%
# print out specific type of error for further analysis

err_cnt = 0
for i in range(0, len(y_test)):
    if(y_test[i]=='male' and y_pred[i]=='female'):
        print(X_test[i])
        err_cnt = err_cnt+1
print("errors:", err_cnt)
# Out:
# Put in her tender heart th’ aspiring flame
# Thy voice is thunder, but thy looks are humble.
# How canst thou urge God’s dreadful law to us
# Say I, her sovereign, am her subject low.
# The bleeding witness of my hatred by,
# Well, hie thee to thy lord. I kiss his hand.
# One raised in blood, and one in blood established;
# In that you brook it ill, it makes him worse.
# Remember Margaret was a prophetess.—
# Lest to thy harm thou move our patience.
# Familiarly shall call thy Dorset brother.
# Could not believe but that I was in hell,
# Shall lose the royalty of England’s throne.
# And in their summer beauty kissed each other.
# Doth comfort thee in thy sleep. Live and flourish.
# What sayst thou now? Speak suddenly. Be brief.
# Amen. And make me die a good old man!
# Your beauty was the cause of that effect—
# O thus, quoth Dighton, lay the gentle babes.
# O, make them joyful. Grant their lawful suit.
# No other harm but loss of such a lord.
# And then, as we have ta’en the sacrament,
# Your country’s fat shall pay your pains the hire.
# He cannot live, I hope, and must not die
# To breakfast once, forth of my company.
# Where be thy tenants and thy followers?
# Have done a drunken slaughter and defaced
# O Margaret, Margaret, now thy heavy curse
# Whom their o’ercloyèd country vomits forth
# Small herbs have grace; great weeds do grow
# And make poor England weep in streams of blood.
# Thy beauty hath, and made them blind with
# And being but a toy, which is no grief to give.
# And yet go current from suspicion.
# Wert thou not banishèd on pain of death?
# Alas! For whose sake did I that ill deed?
# Unto the dignity and height of fortune,
# Courageous Richmond, well hast thou acquit thee.
# And, for more slander to thy dismal seat,
# Of butchered princes fight in thy behalf.
# But thou wilt be avenged on my misdeeds,
# Misconster us in him, and wail his death.
# So that between their titles and low name
# And wet his grave with my repentant tears,
# But shall I live in hope?
# Bid Gloucester think of this, and he will weep.
# Not to kill him, having a warrant,
# O, spare my guiltless wife and my poor children!—
# Than is the doting title of a mother.
# My proud heart sues and prompts my tongue to
# Which here we waken to our country’s good,
# And plant your joys in living Edward’s throne.
# Of the young prince your son. Send straight for
# I would they were, that I might die at once,
# If I did take the kingdom from your sons,
# Sister, have comfort. All of us have cause
# Have done thy charm, thou hateful, withered hag.
# Say, have I thy consent that they shall die?
# proud,
# And some ten voices cried God save King Richard!
# Slave, I have set my life upon a cast,
# sorrow,
# And pitied me, and kindly kissed my cheek,
# Gloucester, we have done deeds of charity,
# Have taken sanctuary. The tender prince
# James Tyrrel, and your most obedient subject.
# Of all one pain, save for a night of groans
# Be satisfied, dear God, with our true blood,
# With politic grave counsel; then the King
# The son, compelled, been butcher to the sire.
# And since, methinks I would not grow so fast
# weeping.
# Unto the kingdom of perpetual night.
# Then cursed she Richard. Then cursed she
# Virtuous and holy, be thou conqueror.
# Teach not thy lip such scorn, for it was made
# But first I’ll turn yon fellow in his grave
# Today shalt thou behold a subject die
# To slay the innocent? What is my offense?
# His wit set down to make his valor live.
# When Richmond was a little peevish boy.
# Were never orphans had so dear a loss.
# Those eyes of thine from mine have drawn salt
# Of thy devotion and right Christian zeal.
# That he will lose his head ere give consent
# Make us Thy ministers of chastisement,
# When thou shalt tell the process of their death.
# errors: 87

# %%
err_cnt = 0
for i in range(0, len(y_test)):
    if(y_test[i]=='female' and y_pred2[i]=='male'):
        print(X_test[i])
        err_cnt = err_cnt+1
print("errors:", err_cnt)
# Out:
# To revel in the entrails of my lambs.
# Yet that, by you deposed, you quake like rebels.—
# I fear me both are false.
# That in your outward action shows itself
# Of these known evils but to give me leave
# I never did incense his Majesty
# What stay had I but Edward? And he’s gone.
# Thou elvish-marked, abortive, rooting hog,
# True, when avoided grace makes destiny.
# Queen?
# Whose deadly web ensnareth thee about?
# O no, my reasons are too deep and dead—
# And so will I.
# The King, on his own royal disposition,
# Stay, I will go with you.
# Saw you the King today, my lord of Derby?
# But with his timorous dreams was still awaked.
# Now, for my life, she’s wandering to the Tower,
# And not be Richard, that hath done all this.
# It is a quarrel just and reasonable
# My damnèd son that thy two sweet sons smothered.
# If ever he have wife, let her be made
# Blush, blush, thou lump of foul deformity,
# I fear our happiness is at the height.
# God grant him health. Did you confer with him?
# And often up and down my sons were tossed
# It is determined, not concluded yet;
# No, by the Holy Rood, thou know’st it well.
# heaven
# My lord, you do me shameful injury
# Whisper the spirits of thine enemies
# To be so baited, scorned, and stormèd at.
# God’s wrong is most of all.
# That I, being governed by the watery moon,
# I prithee, pretty York, who told thee this?
# Whom envy hath immured within your walls—
# If thou hadst feared to break an oath by Him,
# Send her a letter of thy noble deeds;
# Clarence and Edward. O, what cause have I,
# By heaven, I will acquaint his Majesty
# Taken from Paul’s to be interrèd there.
# Whose ugly and unnatural aspect
# Misused ere used, by times ill-used o’erpast.
# Thy deeds, inhuman and unnatural,
# Go, go, poor soul, I envy not thy glory.
# Which issued from my other angel husband
# Insulting tyranny begins to jut
# From cold and empty veins where no blood dwells.
# One heaved a-high to be hurled down below,
# arms
# And will to France, hoping the consequence
# I will confess she was not Edward’s daughter.
# Thy school days frightful, desp’rate, wild, and
# Their aunt I am in law, in love their mother.
# If something thou wouldst swear to be believed,
# And lived with looking on his images;
# Ay, boy.
# A man that loves not me nor none of you.
# Never hung poison on a fouler toad.
# them,
# An honest tale speeds best being plainly told.
# The worm of conscience still begnaw thy soul.
# Thou killed’st my husband Henry in the Tower,
# Hath in eternal darkness folded up.
# I had a Rutland too; thou holp’st to kill him.
# Hereafter time, for time past wronged by thee.
# For I myself have many tears to wash
# In sign of league and amity with thee.
# You envy my advancement, and my friends’.
# I would I were, to be revenged on thee.
# And both the Princes had been breathing here,
# Matched not the high perfection of my loss.
# A cockatrice hast thou hatched to the world,
# Peace, Master Marquess, you are malapert.
# Came to me as I followed Henry’s corse,
# Bear with me. I am hungry for revenge,
# Shall I be tempted of the devil thus?
# O, let me speak!
# So now prosperity begins to mellow
# Where is kind Hastings?
# Poor key-cold figure of a holy king,
# Throw over her the veil of infamy.
# No? Why? When he that is my husband now
# Unless thou couldst put on some other shape
# And loves not me, be you, good lord, assured
# As thou canst yield a melancholy seat,
# furious;
# Who hath committed them?
# Or else I swoon with this dead-killing news!
# God knows, in torment and in agony.
# Prodigious, and untimely brought to light,
# Filled it with cursing cries and deep exclaims.
# Well, well, put up your sword.
# Yet, Derby, notwithstanding she’s your wife
# For she commanding all, obeyed of none.
# But now two mirrors of his princely semblance
# wounds.
# So from thy soul’s love didst thou love her brothers,
# Good faith, good faith, the saying did not hold
# Preys on the issue of his mother’s body
# And that be heir to his unhappiness.
# Within so small a time my woman’s heart
# Here in these confines slyly have I lurked
# curses!
# well.
# If I thought that, I tell thee, homicide,
# Come now towards Chertsey with your holy load,
# A handkerchief, which say to her did drain
# My pretty cousins, you mistake me both.
# Makes him to send, that he may learn the ground.
# Unless it be while some tormenting dream
# If heaven have any grievous plague in store
# The purple sap from her sweet brother’s body,
# Why wither not the leaves that want their sap?
# And mortal eyes cannot endure the devil.—
# If yet your gentle souls fly in the air
# To serve me well, you all should do me duty:
# And cry O Clarence, my unhappy son?
# Tressel and Berkeley, go along with me.
# What likelihood of his amendment, lords?
# I would I knew thy heart.
# Anointed let me be with deadly venom,
# Welcome, destruction, blood, and massacre.
# And all the pleasures you usurp are mine.
# Were red-hot steel to sear me to the brains!
# toad.
# God witness with me, I have wept for thine.
# Thou loathèd issue of thy father’s loins,
# Hover about me with your airy wings
# If this inducement move her not to love,
# God bless thee, and put meekness in thy breast,
# But how long fairly shall her sweet life last?
# not,
# And so wast thou, Lord Hastings, when my son
# Of those gross taunts that oft I have endured.
# O, let me make the period to my curse!
# You cannot guess who caused your father’s death.
# Cousins, indeed, and by their uncle cozened
# I had a Richard too, and thou did’st kill him;
# O, wonderful, when devils tell the truth!
# Madam, farewell.
# Ere from this war thou turn a conqueror,
# Harp on it still shall I till heart-strings break.
# God grant we never may have need of you.
# I pour the helpless balm of my poor eyes.
# Where be the bending peers that flattered thee?
# Of comfort, kingdom, kindred, freedom, life.
# Name him.
# sleep.
# I go. Write to me very shortly,
# That thou dost love my daughter from thy soul.
# No farther than the Tower, and, as I guess,
# O, thou didst prophesy the time would come
# My unblown flowers, new-appearing sweets,
# By Him that raised me to this careful height
# To watch the waning of mine enemies.
# Profaned, dishonored, and the third usurped.
# Look when he fawns, he bites; and when he bites,
# Make war upon themselves, brother to brother,
# Then say they were not slain.
# And plucked two crutches from my feeble hands,
# For she being feared of all, now fearing one;
# Provokes this deluge most unnatural.—
# So long a-growing and so leisurely,
# No, boy.
# Catesby, I come.—Lords, will you go with me?
# The unity the King my husband made
# Where be the thronging troops that followed thee?
# Can curses pierce the clouds and enter heaven?
# A happy and a joyful time of day.
# errors: 170

# %% [markdown]
# ## 5-fold cross validation

# %%
from sklearn import svm

# %%
from sklearn.svm import *

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
svm_clf_pipe = Pipeline([('vect', StemmedCountVectorizer(binary=False, min_df= 5, stop_words = 'english')),('svm', SVC(C= 1, kernel= 'rbf', random_state=42))])
scores = cross_val_score(svm_clf_pipe, X, y, cv=5)
avg=sum(scores)/len(scores)
print(avg)
# Out:
# 0.7713147410358566

# %%
svm_clf_pipe3 = Pipeline([('vect', StemmedCountVectorizer(binary=False, min_df= 5, stop_words = 'english')),('svm', LinearSVC(C=1))])
scores = cross_val_score(svm_clf_pipe3, X, y, cv=5)
avg=sum(scores)/len(scores)
print(avg)
# Out:
# 0.7593625498007969

# %%
svm_clf_pipe4 = Pipeline([('vect', StemmedCountVectorizer(binary=False, min_df= 5, ngram_range= (1,2), stop_words = 'english')),('svm', LinearSVC(C=1))])
scores = cross_val_score(svm_clf_pipe4, X, y, cv=5)
avg=sum(scores)/len(scores)
print(avg)
# Out:
# 0.7556440903054449

# %% [markdown]
# ## Explore other SVM models

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'kernel': ['linear','poly', 'rbf'],
    'C':[1, 3, 5, 8],  # [1, 10, 20, 45]
    #'gamma': ['scale','auto'],
    #'shrinking' : [True,False],
    #'probability': [True,False],
    'verbose': [True],
   # 'decision_function_shape': ['ovo','ovr'],
    #'break_ties': [True,False],
}
svm_model = SVC(random_state=42)

clf_try = GridSearchCV(svm_model, params,  cv=5)
clf_try.fit(X_train_vec_stem, y_train)
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]
# GridSearchCV(cv=5, estimator=SVC(random_state=42),
#              param_grid={'C': [1, 3, 5, 8], 'kernel': ['linear', 'poly', 'rbf'],
#                          'verbose': [True]})

# %%
clf_try.cv_results_
# Out:
# {'mean_fit_time': array([0.09617782, 0.1366765 , 0.12932086, 0.13454404, 0.14962392,
#         0.14562049, 0.19047232, 0.13747416, 0.14719748, 0.28580761,
#         0.15043859, 0.14846063]),
#  'std_fit_time': array([0.00456158, 0.007054  , 0.00270677, 0.00681367, 0.00162559,
#         0.00257753, 0.01853426, 0.00916464, 0.00353858, 0.03555165,
#         0.00490497, 0.00222727]),
#  'mean_score_time': array([0.01100755, 0.01861234, 0.02201285, 0.01040673, 0.01801367,
#         0.02241726, 0.01021061, 0.01740842, 0.02180572, 0.01001229,
#         0.01680875, 0.02180681]),
#  'std_score_time': array([6.27919115e-04, 7.96267205e-04, 6.34086044e-04, 7.97245377e-04,
#         6.32269663e-04, 4.90018392e-04, 3.98727388e-04, 4.88984321e-04,
#         3.99162188e-04, 8.18939188e-06, 4.02963174e-04, 7.47723399e-04]),
#  'param_C': masked_array(data=[1, 1, 1, 3, 3, 3, 5, 5, 5, 8, 8, 8],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'poly', 'rbf', 'linear', 'poly', 'rbf',
#                     'linear', 'poly', 'rbf', 'linear', 'poly', 'rbf'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_verbose': masked_array(data=[True, True, True, True, True, True, True, True, True,
#                     True, True, True],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear', 'verbose': True},
#   {'C': 1, 'kernel': 'poly', 'verbose': True},
#   {'C': 1, 'kernel': 'rbf', 'verbose': True},
#   {'C': 3, 'kernel': 'linear', 'verbose': True},
#   {'C': 3, 'kernel': 'poly', 'verbose': True},
#   {'C': 3, 'kernel': 'rbf', 'verbose': True},
#   {'C': 5, 'kernel': 'linear', 'verbose': True},
#   {'C': 5, 'kernel': 'poly', 'verbose': True},
#   {'C': 5, 'kernel': 'rbf', 'verbose': True},
#   {'C': 8, 'kernel': 'linear', 'verbose': True},
#   {'C': 8, 'kernel': 'poly', 'verbose': True},
#   {'C': 8, 'kernel': 'rbf', 'verbose': True}],
#  'split0_test_score': array([0.77039848, 0.77988615, 0.78937381, 0.74762808, 0.78368121,
#         0.78747628, 0.74383302, 0.78368121, 0.78368121, 0.74003795,
#         0.78557875, 0.77609108]),
#  'split1_test_score': array([0.78178368, 0.79316888, 0.78557875, 0.74762808, 0.79127135,
#         0.75711575, 0.74383302, 0.78937381, 0.74762808, 0.73055028,
#         0.78937381, 0.73624288]),
#  'split2_test_score': array([0.77039848, 0.78937381, 0.79316888, 0.72865275, 0.79506641,
#         0.75901328, 0.71916509, 0.78937381, 0.74383302, 0.72296015,
#         0.78747628, 0.74003795]),
#  'split3_test_score': array([0.75332068, 0.78557875, 0.78368121, 0.74573055, 0.77988615,
#         0.77229602, 0.73814042, 0.77798861, 0.77039848, 0.72865275,
#         0.77798861, 0.76470588]),
#  'split4_test_score': array([0.79316888, 0.78557875, 0.77988615, 0.76470588, 0.77988615,
#         0.80455408, 0.76091082, 0.78178368, 0.78747628, 0.75332068,
#         0.77988615, 0.76850095]),
#  'mean_test_score': array([0.77381404, 0.78671727, 0.78633776, 0.74686907, 0.78595825,
#         0.77609108, 0.74117647, 0.78444023, 0.76660342, 0.73510436,
#         0.78406072, 0.75711575]),
#  'std_test_score': array([0.01327731, 0.00442577, 0.0045856 , 0.01142309, 0.00616625,
#         0.01792139, 0.0133961 , 0.00442577, 0.01800158, 0.01063973,
#         0.00439311, 0.01596636]),
#  'rank_test_score': array([ 7,  1,  2, 10,  3,  6, 11,  4,  8, 12,  5,  9])}

# %%
clf_try.best_params_
# Out:
# {'C': 1, 'kernel': 'poly', 'verbose': True}

# %%
clf_poly = SVC(C= 1, kernel= 'poly', random_state=42)

# %%
clf_poly.fit(X_train_vec_stem, y_train)
# Out:
# SVC(C=1, kernel='poly', random_state=42)

# %%
clf_poly.score(X_test_vec_stem,y_test)
# Out:
# 0.7831858407079646

# %%
clf_poly.predict(X_test_vec_stem)
# Out:
# array(['male', 'male', 'male', ..., 'male', 'male', 'male'], dtype=object)

# %%
y_pred = clf_poly.predict(X_test_vec_stem)
cm=confusion_matrix(y_test, y_pred2, labels=['male','female'])
print(cm)
print()

target_names = ['male','female']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# [[782  89]
#  [170  89]]
#
#               precision    recall  f1-score   support
#
#         male       0.68      0.10      0.18       259
#       female       0.79      0.99      0.88       871
#
#     accuracy                           0.78      1130
#    macro avg       0.73      0.54      0.53      1130
# weighted avg       0.76      0.78      0.72      1130

# %% [markdown]
# ## Bigrams, stemmed

# %%
params = {
    'kernel': [ 'poly', 'rbf', 'linear'],
    'C':[1, 2, 3, 5, 10],
    #'gamma': ['scale','auto'],
    #'shrinking' : [True,False],
    #'probability': [True,False],
    'verbose': [True],
   # 'decision_function_shape': ['ovo','ovr'],
    #'break_ties': [True,False],
}
svm_model = SVC(random_state=42)

clf_bi = GridSearchCV(svm_model, params,  cv=3)
clf_bi.fit(X_train_gram_vec_stem, y_train)
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]
# GridSearchCV(cv=3, estimator=SVC(random_state=42),
#              param_grid={'C': [1, 2, 3, 5, 10],
#                          'kernel': ['poly', 'rbf', 'linear'],
#                          'verbose': [True]})

# %%
clf_bi.cv_results_
# Out:
# {'mean_fit_time': array([0.09062529, 0.09392269, 0.06972226, 0.11100856, 0.10259477,
#         0.08215332, 0.10927463, 0.10869408, 0.08927782, 0.09503023,
#         0.11836473, 0.12502027, 0.1120313 , 0.10389892, 0.20796514]),
#  'std_fit_time': array([0.00196376, 0.00122795, 0.00255812, 0.01653199, 0.00044582,
#         0.00700676, 0.00634434, 0.00410773, 0.00416231, 0.00082328,
#         0.01065436, 0.01468348, 0.01414173, 0.00066876, 0.02104227]),
#  'mean_score_time': array([0.02700408, 0.0330108 , 0.01667428, 0.02800568, 0.03467361,
#         0.01600512, 0.02767555, 0.03467568, 0.01467808, 0.02800481,
#         0.03440086, 0.01567197, 0.02800059, 0.03201111, 0.0140113 ]),
#  'std_score_time': array([8.24613579e-04, 3.10453176e-06, 4.64964400e-04, 2.15884604e-03,
#         1.69788002e-03, 8.17218864e-04, 2.06153809e-03, 2.49398312e-03,
#         4.73351627e-04, 8.15074920e-04, 1.98012264e-03, 4.68167203e-04,
#         8.43161723e-06, 8.07058696e-04, 7.67479080e-06]),
#  'param_C': masked_array(data=[1, 1, 1, 2, 2, 2, 3, 3, 3, 5, 5, 5, 10, 10, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['poly', 'rbf', 'linear', 'poly', 'rbf', 'linear',
#                     'poly', 'rbf', 'linear', 'poly', 'rbf', 'linear',
#                     'poly', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_verbose': masked_array(data=[True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'poly', 'verbose': True},
#   {'C': 1, 'kernel': 'rbf', 'verbose': True},
#   {'C': 1, 'kernel': 'linear', 'verbose': True},
#   {'C': 2, 'kernel': 'poly', 'verbose': True},
#   {'C': 2, 'kernel': 'rbf', 'verbose': True},
#   {'C': 2, 'kernel': 'linear', 'verbose': True},
#   {'C': 3, 'kernel': 'poly', 'verbose': True},
#   {'C': 3, 'kernel': 'rbf', 'verbose': True},
#   {'C': 3, 'kernel': 'linear', 'verbose': True},
#   {'C': 5, 'kernel': 'poly', 'verbose': True},
#   {'C': 5, 'kernel': 'rbf', 'verbose': True},
#   {'C': 5, 'kernel': 'linear', 'verbose': True},
#   {'C': 10, 'kernel': 'poly', 'verbose': True},
#   {'C': 10, 'kernel': 'rbf', 'verbose': True},
#   {'C': 10, 'kernel': 'linear', 'verbose': True}],
#  'split0_test_score': array([0.78498294, 0.7883959 , 0.75654152, 0.78612059, 0.77588168,
#         0.73720137, 0.78270762, 0.77133106, 0.72696246, 0.78270762,
#         0.76564278, 0.70989761, 0.78498294, 0.7440273 , 0.70193402]),
#  'split1_test_score': array([0.78701595, 0.78018223, 0.7881549 , 0.78587699, 0.78246014,
#         0.76651481, 0.78359909, 0.77676538, 0.74373576, 0.77790433,
#         0.76309795, 0.73348519, 0.77790433, 0.75512528, 0.7357631 ]),
#  'split2_test_score': array([0.77790433, 0.77334852, 0.77220957, 0.77220957, 0.76879271,
#         0.74829157, 0.77107062, 0.761959  , 0.73690205, 0.76309795,
#         0.75854214, 0.73462415, 0.76537585, 0.75056948, 0.72437358]),
#  'mean_test_score': array([0.78330107, 0.78064222, 0.772302  , 0.78140238, 0.77571151,
#         0.75066925, 0.77912578, 0.77001848, 0.73586676, 0.77456997,
#         0.76242762, 0.72600232, 0.77608771, 0.74990735, 0.72069023]),
#  'std_test_score': array([0.00390529, 0.00615167, 0.01290627, 0.00650106, 0.005581  ,
#         0.01208469, 0.00570747, 0.00611552, 0.00688669, 0.00834559,
#         0.00293732, 0.01139724, 0.00810697, 0.00455486, 0.01405411]),
#  'rank_test_score': array([ 1,  3,  8,  2,  6, 11,  4,  9, 13,  7, 10, 14,  5, 12, 15])}

# %%
clf_bi.best_params_
# Out:
# {'C': 1, 'kernel': 'poly', 'verbose': True}

# %%
clf_poly_gram = SVC(C= 1, kernel= 'rbf', random_state=42)
clf_poly_gram.fit(X_train_gram_vec_stem, y_train)
# Out:
# SVC(C=1, random_state=42)

# %%
clf_poly_gram.score(X_test_gram_vec_stem,y_test)
# Out:
# 0.7778761061946903

# %%
y_pred2 = clf_poly.predict(X_test_vec_stem)
cm=confusion_matrix(y_test, y_pred2, labels=['male','female'])
print(cm)
print()

target_names = ['male','female']
print(classification_report(y_test, y_pred2, target_names=target_names))
# Out:
# [[858  13]
#  [232  27]]
#
#               precision    recall  f1-score   support
#
#         male       0.68      0.10      0.18       259
#       female       0.79      0.99      0.88       871
#
#     accuracy                           0.78      1130
#    macro avg       0.73      0.54      0.53      1130
# weighted avg       0.76      0.78      0.72      1130
